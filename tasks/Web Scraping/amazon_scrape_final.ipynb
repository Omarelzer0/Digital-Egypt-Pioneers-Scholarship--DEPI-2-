# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# Function to extract Product Title
def get_title(soup):

    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id":'productTitle'})
        
        # Inner NavigatableString Object
        title_value = title.text

        # Title as a string value
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

# Function to extract Product Price
def get_price(soup):

    try:
        price = soup.find("span", attrs={'class':'a-offscreen'}).string.strip()

    except AttributeError:

        try:
            # If there is some deal price
            price = soup.find("span", attrs={'class':'priceblock_dealprice'}).string.strip()

        except:
            price = ""

    return price

# Function to extract Product Rating
def get_rating(soup):

    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
    
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = ""	

    return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()

    except AttributeError:
        review_count = ""	

    return review_count

# Function to extract Availability Status
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()

    except AttributeError:
        available = "Not Available"	

    return available

# %%
if __name__ == '__main__':

    # add your user agent 
    HEADERS = ({'User-Agent':'', 'Accept-Language': 'en-US, en;q=0.5'})

    # The webpage URL
    URL = "https://www.amazon.com/s?k=playstation+4&ref=nb_sb_noss_2"

    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)

    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "html.parser")

    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})

    # Store the links
    links_list = []

    # Loop for extracting links from Tag Objects
    for link in links:
            links_list.append(link.get('href'))

    d = {"title":[], "price":[], "rating":[], "reviews":[],"availability":[]}
    
    # Loop for extracting product details from each link 
    for link in links_list:
        new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d['title'].append(get_title(new_soup))
        d['price'].append(get_price(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['reviews'].append(get_review_count(new_soup))
        d['availability'].append(get_availability(new_soup))

    
    amazon_df = pd.DataFrame.from_dict(d)
    amazon_df['title'].replace('', np.nan, inplace=True)
    amazon_df = amazon_df.dropna(subset=['title'])
    amazon_df.to_csv("amazon_data.csv", header=True, index=False)
# Out:
# C:\Users\20101\AppData\Local\Temp\ipykernel_31524\4254666078.py:42: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   amazon_df['title'].replace('', np.nan, inplace=True)

# %%
amazon_df
# Out:
#                                                 title    price  \
# 0              Sony Playstation PS4 1TB Black Console  $200.00
# 1   Sony PlayStation 4 Slim 1TB Premium Bundle (Re...  $274.99
# 2   Playstation Sony 4, 500GB Slim System [CUH-221...  $189.99
# 3   PlayStation®4 Console – Call of Duty® Modern W...  $379.92
# 4   PlayStation 4 Slim 500GB Console - Uncharted 4...  $279.99
# 5   Sony PlayStation 4 Pro 1TB Console - Black (PS...  $199.00
# 6     PlayStation 4 Slim 500GB Console [Discontinued]  $119.75
# 7   PlayStation 4 Slim 1TB Limited Edition Console...  $299.99
# 8   FASIGO PS4 Controller 2 Pack, Wireless PS4 Con...   $31.98
# 9   Sony Playstation 4 Slim(CUH-2215B) 1TB Core wi...  $243.90
# 10  PS4 Controller Charger Dock Station, OIVO 1.8H...   $14.99
# 11           Star Wars Jedi: Survivor - PlayStation 4   $19.97
# 12    $250 PlayStation Store Gift Card [Digital Code]  $250.00
# 13                    Sonic Frontiers - PlayStation 4   $29.00
# 14  PlayStation 4 Slim 1TB Console - Call of Duty:...  $200.00
# 15  Sony Playstation 4 w/ Accessories, 500GB, CUH-...  $144.75
# 16       Sony PlayStation 2 Console - Black (Renewed)  $184.79
# 17            Xbox 360 250GB Slim Console - (Renewed)  $154.95
# 18  Sony Playstation 3 160GB CECH-3001A, Console O...  $149.99
# 19  PXN Gaming Steering Wheel - V9 GEN2 Xbox Racin...  $159.99
# 20  GamingBoy 2 Pack Wireless Controller for PS4/P...   $35.99
# 21  PS1/PS2 to HDMI Converter, RGBS & YPbPr Signal...   $25.99
#
#                                          rating          reviews  \
# 0                            4.6 out of 5 stars    1,566 ratings
# 1   Previous page of related Sponsored Products
# 2                            4.3 out of 5 stars      374 ratings
# 3                            4.5 out of 5 stars      120 ratings
# 4                            4.8 out of 5 stars    6,500 ratings
# 5                            4.4 out of 5 stars    4,137 ratings
# 6                            4.5 out of 5 stars    1,912 ratings
# 7                            4.3 out of 5 stars      736 ratings
# 8                            4.2 out of 5 stars      544 ratings
# 9                            3.8 out of 5 stars       31 ratings
# 10                           4.7 out of 5 stars   39,612 ratings
# 11                           4.0 out of 5 stars       20 ratings
# 12                           4.6 out of 5 stars  262,757 ratings
# 13                           4.7 out of 5 stars      977 ratings
# 14                           4.6 out of 5 stars    1,025 ratings
# 15                           3.3 out of 5 stars       38 ratings
# 16                           4.0 out of 5 stars    1,528 ratings
# 17                           3.8 out of 5 stars      862 ratings
# 18                           4.1 out of 5 stars      382 ratings
# 19                           5.0 out of 5 stars        3 ratings
# 20                           4.5 out of 5 stars        5 ratings
# 21                           4.3 out of 5 stars       19 ratings
#
#                            availability
# 0    Only 4 left in stock - order soon.
# 1
# 2    Only 8 left in stock - order soon.
# 3   Only 15 left in stock - order soon.
# 4   Only 11 left in stock - order soon.
# 5    Only 2 left in stock - order soon.
# 6    Only 1 left in stock - order soon.
# 7    Only 1 left in stock - order soon.
# 8                              In Stock
# 9    Only 1 left in stock - order soon.
# 10                             In Stock
# 11                             In Stock
# 12                        Available now
# 13  Only 17 left in stock - order soon.
# 14  Only 15 left in stock - order soon.
# 15   Only 6 left in stock - order soon.
# 16                             In Stock
# 17                             In Stock
# 18   Only 6 left in stock - order soon.
# 19                             In Stock
# 20                             In Stock
# 21                             In Stock
